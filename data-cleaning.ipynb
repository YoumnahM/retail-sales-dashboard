# %%
import pandas as pd

# Load datasets
stores_df = pd.read_csv("stores.csv")
features_df = pd.read_csv("features.csv")
train_df = pd.read_csv("train.csv")

# Preview
print("📁 stores.csv")
display(stores_df.head())

print("\n📁 features.csv")
display(features_df.head())

print("\n📁 train.csv")
display(train_df.head())
# Out:
# 📁 stores.csv
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875
# 📁 features.csv
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# ...

# %%
features_df = pd.read_csv("features.csv")
features_df['Date'] = features_df['Date'].astype(str).str.strip()
features_df['Date'] = pd.to_datetime(features_df['Date'], errors='coerce')
print("Missing date:", features_df['Date'].isnull().sum())
print("Date range:", features_df['Date'].min(), "to", features_df['Date'].max())
print(features_df['Date'].dtype)
# Out:
# Missing date: 0
# Date range: 2010-02-05 00:00:00 to 2013-07-26 00:00:00
# datetime64[ns]

# %%
#step 1: Convert 'Date' column to datetime format
train_df = pd.read_csv("train.csv")
train_df['Date'] = pd.to_datetime(train_df['Date'], errors='coerce')

print(train_df['Date'].isnull().sum())
# Out:
# 0

# %%
#Step 2: Fill missing values 
# Fill Markdown columns with 0 (assuming no markdown means no discount)
markdown_cols = ['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5']
features_df[markdown_cols] = features_df[markdown_cols].fillna(0)

#Sort before forward fill/backward fill
features_df.sort_values(by=['Store', 'Date'], inplace=True)

# Forward fill missing values for 'CPI', 'Unemployment'
features_df['CPI'] = features_df.groupby('Store')['CPI'].ffill().bfill()
features_df['Unemployment'] = features_df.groupby('Store')['Unemployment'].ffill().bfill()

#Check for any remaining missing values
print("\nRemaining missing values in features_df:")
print(features_df.isnull().sum())
# Out:
# Remaining missing values in features_df:
# Store           0
# Date            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday       0
# dtype: int64

# %%
print("Missing values in train_df:")
print(train_df.isnull().sum())
# Out:
# Missing values in train_df:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
# Merging datasets
# Step 1: Merge train with features on Store and Date
merged_df = pd.merge(train_df, features_df, on=['Store', 'Date'], how='left')

# Step 2: Merge with stores on Store
merged_df = pd.merge(merged_df, stores_df, on='Store', how='left')

# Step 3: Check for any remaining missing values
print("\nRemaining missing values after merging:")
print(merged_df.isnull().sum())

# preview merged dataset
merged_df.head()
# Out:
# Remaining missing values after merging:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday_x     0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday_y     0
# Type            0
# Size            0
# dtype: int64
#    Store  Dept       Date  Weekly_Sales  IsHoliday_x  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50        False        42.31       2.572
# 1      1     1 2010-02-12      46039.49         True        38.51       2.548
# 2      1     1 2010-02-19      41595.55        False        39.93       2.514
# 3      1     1 2010-02-26      19403.54        False        46.63       2.561
# 4      1     1 2010-03-05      21827.90        False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# ...

# %%
#add columns for year, month, and day
merged_df['Year'] = merged_df['Date'].dt.year
merged_df['Month'] = merged_df['Date'].dt.month
merged_df['Month_Name'] = merged_df['Date'].dt.strftime('%B')
merged_df['Week'] = merged_df['Date'].dt.isocalendar().week
merged_df['Day'] = merged_df['Date'].dt.day
merged_df['DayOfWeek'] = merged_df['Date'].dt.day_of_week
merged_df['Day_Name'] = merged_df['Date'].dt.strftime('%A')

merged_df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday_x  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50        False        42.31       2.572
# 1      1     1 2010-02-12      46039.49         True        38.51       2.548
# 2      1     1 2010-02-19      41595.55        False        39.93       2.514
# 3      1     1 2010-02-26      19403.54        False        46.63       2.561
# 4      1     1 2010-03-05      21827.90        False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  ...  IsHoliday_y  Type    Size  Year  \
# 0        0.0        0.0        0.0  ...        False     A  151315  2010
# 1        0.0        0.0        0.0  ...         True     A  151315  2010
# 2        0.0        0.0        0.0  ...        False     A  151315  2010
# 3        0.0        0.0        0.0  ...        False     A  151315  2010
# 4        0.0        0.0        0.0  ...        False     A  151315  2010
#
#    Month Month_Name  Week  Day  DayOfWeek Day_Name
# ...

# %%
# Define holiday dates
superbowl_dates = pd.to_datetime(['2010-02-12', '2011-02-11', '2012-02-10', '2013-02-08'])
laborday_dates = pd.to_datetime(['2010-09-10', '2011-09-09', '2012-09-07', '2013-09-06'])
thanksgiving_dates = pd.to_datetime(['2010-11-26', '2011-11-25', '2012-11-23', '2013-11-29'])
christmas_dates = pd.to_datetime([
    '2010-12-23', '2010-12-24', '2010-12-31',
    '2011-12-23', '2011-12-24', '2011-12-30',
    '2012-12-24', '2012-12-28',
    '2013-12-27'
])

# Add holiday indicator columns
merged_df['IsSuperBowl'] = merged_df['Date'].isin(superbowl_dates).astype('object')
merged_df['IsLaborDay'] = merged_df['Date'].isin(laborday_dates).astype('object')
merged_df['IsThanksgiving'] = merged_df['Date'].isin(thanksgiving_dates).astype('object')
merged_df['IsChristmas'] = merged_df['Date'].isin(christmas_dates).astype('object')

# %%
merged_df.to_csv("merged_data.csv", index=False)

# %%
import pandas as pd

# 1. Load the dataset
df = pd.read_csv("merged_data.csv")

# 2. Create the mapping of Store number to city name (1–45)
store_cities = [
    "Springfield", "Riverside", "Franklin", "Greenville", "Bristol",
    "Clinton", "Fairview", "Madison", "Georgetown", "Salem",
    "Ashland", "Oxford", "Milton", "Centerville", "Clayton",
    "Jackson", "Arlington", "Oakland", "Manchester", "Newport",
    "Lexington", "Cleveland", "Cambridge", "Kingston", "Auburn",
    "Winchester", "Hudson", "Monroe", "Florence", "Burlington",
    "Dover", "Lancaster", "Albany", "Bedford", "Concord",
    "Harrison", "Jefferson", "Marion", "Richmond", "Troy",
    "Trenton", "Warren", "Hamilton", "Dayton", "Fayetteville"
]

store_names = {i+1: city for i, city in enumerate(store_cities)}

# 3. Map store numbers to names
df['Store_Name'] = df['Store'].map(store_names)

# 4. Save the updated DataFrame to the same file (overwrite)
df.to_csv("merged_data.csv", index=False)

# 5. Confirm it's there
print("✅ Store_Name column added and saved to merged_data.csv")
print(df[['Store', 'Store_Name']].drop_duplicates().sort_values('Store').head())
# Out:
# ✅ Store_Name column added and saved to merged_data.csv
#        Store   Store_Name
# 0          1  Springfield
# 10244      2    Riverside
# 20482      3     Franklin
# 29518      4   Greenville
# 39790      5      Bristol

# %%
import pandas as pd

# 1. Load your dataset
df = pd.read_csv("merged_data.csv")

# 2. Create a mapping of department numbers to names (sample realistic names)
dept_names = {
    1: "Grocery", 2: "Pharmacy", 3: "Clothing", 4: "Electronics", 5: "Toys",
    6: "Home Decor", 7: "Furniture", 8: "Automotive", 9: "Sports & Outdoors", 10: "Books",
    11: "Baby", 12: "Shoes", 13: "Jewelry", 14: "Beauty", 15: "Garden",
    16: "Office Supplies", 17: "Pet Supplies", 18: "Hardware", 19: "Beverages", 20: "Snacks",
    21: "Stationery", 22: "Kitchenware", 23: "Seasonal", 24: "Health & Wellness", 25: "Tools",
    26: "Crafts", 27: "Music & Movies", 28: "Cleaning Supplies", 29: "Storage", 30: "Bakery",
    31: "Meat", 32: "Seafood", 33: "Produce", 34: "Dairy", 35: "Frozen Foods",
    36: "Cereal", 37: "Condiments", 38: "Pasta & Rice", 39: "Canned Goods", 40: "Breakfast",
    41: "Ethnic Foods", 42: "Bedding", 43: "Bath", 44: "Lighting", 45: "Paint",
    46: "Flooring", 47: "Window Treatments", 48: "Electronics Accessories", 49: "Video Games", 50: "Luggage",
    51: "Travel Accessories", 52: "Smart Home", 53: "Watches", 54: "Eyewear", 55: "Party Supplies",
    56: "Greeting Cards", 57: "Car Care", 58: "Safety Equipment", 59: "First Aid", 60: "Medical Equipment",
    61: "Vitamins", 62: "Hair Care", 63: "Skin Care", 64: "Makeup", 65: "Fragrances",
    66: "Household Appliances", 67: "Wireless", 68: "Batteries", 69: "School Supplies", 70: "Games & Puzzles",
    71: "Digital Downloads", 72: "Gift Cards", 73: "Smartphones", 74: "Tablets", 75: "Lawn & Garden Tools",
    76: "Grills & Outdoor Cooking", 77: "Patio Furniture", 78: "Fitness Equipment", 79: "Camping Gear", 80: "Bicycles",
    81: "Infant Clothing", 82: "Kids Clothing", 83: "Men's Clothing", 84: "Women's Clothing", 85: "Undergarments",
    86: "Socks & Hosiery", 87: "Accessories", 88: "Footwear Accessories", 89: "Cleaning Tools", 90: "Air Fresheners",
    91: "Trash Bags", 92: "Laundry Supplies", 93: "Dishwashing", 94: "Light Bulbs", 95: "Storage Bins",
    96: "Bathroom Essentials", 97: "Shaving Products", 98: "Incontinence", 99: "Other"
}

# 3. Map Dept to Dept_Name
df['Dept_Name'] = df['Dept'].map(dept_names)

# 4. Save the updated dataset
df.to_csv("merged_data.csv", index=False)

# 5. Check sample
print("✅ Dept_Name column added and saved to merged_data.csv")
print(df[['Dept', 'Dept_Name']].drop_duplicates().sort_values('Dept').head())
# Out:
# ✅ Dept_Name column added and saved to merged_data.csv
#      Dept    Dept_Name
# 0       1      Grocery
# 143     2     Pharmacy
# 286     3     Clothing
# 429     4  Electronics
# 572     5         Toys
